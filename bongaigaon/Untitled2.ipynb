# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
input_path = "2D_images_train/"
output_path = "2D_images_train_temp/"

# %%
img = cv2.imread(input_path+"0_1.png")

# %%
plt.imshow(img)
